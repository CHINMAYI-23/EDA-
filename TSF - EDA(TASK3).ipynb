# %% [markdown]
# # Author : CHINMAYI SS

# %% [markdown]
# # GRIP @ The Sparks Foundation

# %% [markdown]
# # TASK3 : Explonatory Data Analysis in Reatil

# %%
# Importing all the libraries needed in this notebook
import numpy as np
import pandas as pd
import seaborn as sns
from plotnine import *
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 1 : Reading the Dataset

# %%
sample = pd.read_csv(r"C:\Users\chinm\Downloads\SampleSuperstore (1).csv")

# %%
sample.head() # loads the first five rows of the dataset
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
sample.tail() # loads the last five rows of the dataset
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
sample.shape # Number of elements in each dimension of an array
# Out:
# (9994, 13)

# %% [markdown]
# # Step 2 : Checking for the data's information, i.e type

# %%
sample.info() # Returns the concise summary of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
sample.describe()  # Gives the statistical data
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
sample.isnull().sum() # Checks the missing values.
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# # Step 3 : Checking for the duplicate data. If yes, then dropping those data.

# %%
sample.duplicated().sum() # Checks the duplicated data
# Out:
# 17

# %%
sample.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
sample.nunique() #Displays the unique data now
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# # Step 4 : Checking statistical relation between the various rows & columns

# %%
# Correlation between variables
sample.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
# covariance of columns 
sample.cov()
# Out:
#               Postal Code          Sales    Quantity    Discount  \
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228
# Quantity     9.104159e+02     278.459923    4.951113    0.003961
# Discount     3.868704e+02      -3.627228    0.003961    0.042622
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173
#
#                     Profit
# Postal Code -225045.849445
# Sales         69944.096586
# Quantity         34.534769
# Discount        -10.615173
# Profit        54877.798055

# %%
sample.head() # loads the first five rows
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# # Step 5 : Data Visualization

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category', 'Category', data=sample)
plt.title('Category vs Sub Category')
plt.xlabel('Sub-Category')
plt.ylabel('Category')
plt.xticks(rotation=45)
plt.show()

# %%
sample.corr() # Checking the correlation
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sample.hist(bins=50,figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Postal Code'}>,
#         <AxesSubplot:title={'center':'Sales'}>],
#        [<AxesSubplot:title={'center':'Quantity'}>,
#         <AxesSubplot:title={'center':'Discount'}>],
#        [<AxesSubplot:title={'center':'Profit'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ##So, the data here is not normal as revealed by this histogram

# %%
# Count the total repeatable states
sample['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
plt.figure(figsize=(15,15))
sns.countplot(x=sample['State'])
plt.xticks(rotation=90)
plt.title("STATE")
plt.show()

# %%
Profit_plot = (ggplot(sample, aes(x='Sub-Category', y='Profit', fill='Sub-Category')) + geom_col() + coord_flip() +
                scale_fill_brewer(type='div', palette="Spectral") + theme_classic() + ggtitle('Pie Chart'))

display(Profit_plot)
# Out:
# <ggplot: (105307812587)>

# %% [markdown]
# ## The above pie chart shows the profit and loss of each and every sub-categories.

# %%
sns.set(style="whitegrid")
plt.figure(2, figsize=(20,15))
sns.barplot(x='Sub-Category', y='Profit', data=sample, palette="Spectral")
plt.suptitle('Pie Consumption Patterns in the United States', fontsize=16)
plt.show()

# %%
ggplot(sample, aes(x='Ship Mode', fill='Category')) + geom_bar(stat = 'count')
# Out:
# <ggplot: (105307658069)>

# %%
figsize=(15,10)
sns.pairplot(sample,hue='Sub-Category')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
flip_xlabels = theme(axis_text_x = element_text(angle=90, hjust=1), figure_size=(10,5),
                     axis_ticks_length_major=10, axis_ticks_length_minor=5)
(ggplot(sample, aes(x='Sub-Category', fill='Sales')) + geom_bar() + facet_wrap(['Segment'])
 + flip_xlabels +theme(axis_text_x = element_text(size=12)) + ggtitle('Sales From Every Segment Of United States of Whole Data'))
# Out:
# <ggplot: (105306628636)>

# %%
flip_xlabels = theme(axis_text_x = element_text(angle=90, hjust=1), figure_size=(10,5),
                     axis_ticks_length_major=10, axis_ticks_length_minor=5)
(ggplot(sample, aes(x='Sub-Category', fill='Discount')) + geom_bar() + facet_wrap(['Segment'])
 + flip_xlabels +theme(axis_text_x = element_text(size=12)) + ggtitle('Discount on Categories from Every Segment Of United States of Whole Data'))
# Out:
# <ggplot: (105295105431)>

# %%
flip_xlabels = theme(axis_text_x = element_text(angle=90, hjust=1), figure_size=(10,10),
                     axis_ticks_length_major=50, axis_ticks_length_minor=50)
(ggplot(sample, aes(x='Category', fill='Sales')) + geom_bar() + theme(axis_text_x = element_text(size=10))
 + facet_wrap(['Region']) + flip_xlabels+ ggtitle("Sales From Every Region Of United States of Whole Data"))
# Out:
# <ggplot: (105307808028)>

# %%
plt.figure(figsize=(10,4))
sns.lineplot('Discount', 'Profit', data=sample , color='Yellow', label='Discount')
plt.legend()
plt.show()

# %% [markdown]
# # RESULT AND CONCLUSION
#
# 1. Profit is more than that of Sales but there are some areas where profit could be increased.
# 2. Sub-Category : Copiers has the Highest Profit and Sales.
# 3. Sub-Category :
#    Binders has suffered Highest Profit as well as Loss may be due to some factors like discount.
#    Machines suffered highest loss .
#    There are other sub-categories too haven't faced any kind of losses but their profit margins are also low.
# 4. Category : Maximum Sales and Profit has obtained in Technology.
# 5. Category : Minimum Profit has obtained in Furniture category.
# 6. Consumer segment has the highest Sales followed by Corporates.
# 7. Home-Office segment has less sales.
# 8. Western Region has Highest Sales followed by Eastern Region.
#
# From the above data visualization we can see that states and the category where sales and profits are high or less. We can improve in those states by providing some discounts in preffered range so that all company and consumer will both be in profit.
# Most of the heavy discounts are during festivals, end-of-season and clearance sales which are necessary so that the store can make space in their warehouses for fresh stock. Therefore, small losses from discounts are an essential part of company's businesss as company gains in the future by attracting the more long-term customers.
